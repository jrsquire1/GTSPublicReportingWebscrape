# %% [markdown]
# # GTSWebscrape

# %% [markdown]
# ### Runs through all pages AND PREVENTS duplicates H3 elements

# %%
import requests
import re
import pandas as pd
from bs4 import BeautifulSoup

# Initialize an empty list to store data for CSV export and a set to track processed PIDs.
data_for_csv = []
processed_pids = set()

# Loop through pages
page = 0
while True:
    # Update the base URL to include the current page number
    base_url = f'https://publicreporting.sts.org/gtsd?page={page}'
    response = requests.get(base_url)
    bs = BeautifulSoup(response.content, 'html.parser')

    # Regular expression pattern to match '/gtsd-participant/' followed by any number of digits
    pattern = re.compile(r'/gtsd-participant/\d+')

    # Find all links that match the pattern
    links = bs.find_all('a', href=pattern)
    print(f'Processing page: {page}, found {len(links)} links')

    # If no links are found on the current page, exit the loop
    if not links:
        break

    for link in links:
        digits = re.findall(r'\d+', link['href'])
        pid = int(digits[0]) if digits else None

        # Check if this pid has already been processed
        if pid in processed_pids:
            print(f'Skipping already processed PID: {pid}')
            continue  # Skip this pid as it's already been processed
        else:
            processed_pids.add(pid)  # Mark this pid as processed

        url = f'https://publicreporting.sts.org{link["href"]}'
        response = requests.get(url)
        soup = BeautifulSoup(response.content, 'html.parser')
        print(f'Processing link: {url}')

        # Extract hospital, location, and procedure timeframe information.
        hospital = soup.find('h1').text.strip() if soup.find('h1') else "No Hospital Name"
        location_full = soup.find('div', {'class': 'hospital'}).text.strip() if soup.find('div', {'class': 'hospital'}) else "No Location"
        parts = location_full.split('—')
        location = parts[1].strip() if len(parts) > 1 else "Not available"

        procedure_timeframe = "Not available"
        h3_tags = soup.find_all('h3')
        if len(h3_tags) >= 2:
            procedure_timeframe_full = h3_tags[1].get_text(strip=True)
            match = re.search(r'\(([^)]+)\)', procedure_timeframe_full)
            procedure_timeframe = match.group(1) if match else procedure_timeframe

        # Process the page content starting from the second h3 element.
        h3_elements = soup.find_all('h3')[1:]  # Start from the second occurrence
        for h3 in h3_elements:
            category = h3.text.strip() if h3 else "Unknown Category"
            next_sibling = h3.find_next_sibling() if h3 else None

            while next_sibling and next_sibling.name != 'table':
                next_sibling = next_sibling.find_next_sibling()

            if next_sibling and next_sibling.name == 'table':
                rows = next_sibling.find_all('tr')
                for row in rows:
                    description = row.find('td').text.strip() if row.find('td') else "No Description"
                    score = row.find('div', class_='score').text.strip() if row.find('div', class_='score') else "No Score"
                    interval = row.find('div', class_='interval').text.strip() if row.find('div', class_='interval') else "No Interval"
                    report_card_element = row.find('div', class_='report-card-score')
                    report_card_score = report_card_element.text.strip() if report_card_element else "No Report Card Score"

                    # Add data to the list for CSV export.
                    data_for_csv.append({
                        'PID': pid,
                        'Hospital': hospital,
                        'Location': location,
                        'Procedure Timeframe': procedure_timeframe,
                        'Category': category,
                        'Description': description,
                        'Score': score,
                        'Interval': interval,
                        'Report Card Score': report_card_score
                    })

    # Increment the page number for the next iteration
    page += 1

# Create a DataFrame from the list of dictionaries and export to CSV.
if data_for_csv:
    df = pd.DataFrame(data_for_csv)
    df.to_csv('GTSWebscrape.csv', index=False)
    print("Data exported to CSV")
else:
    print("No data available for CSV export.")
# Out:
# Processing page: 0, found 46 links
# Processing link: https://publicreporting.sts.org/gtsd-participant/41009
# Skipping already processed PID: 41009
# Processing link: https://publicreporting.sts.org/gtsd-participant/40013
# Skipping already processed PID: 40013
# Skipping already processed PID: 40013
# Skipping already processed PID: 40013
# Skipping already processed PID: 40013
# Processing link: https://publicreporting.sts.org/gtsd-participant/40216
# Skipping already processed PID: 40216
# Processing link: https://publicreporting.sts.org/gtsd-participant/40324
# Skipping already processed PID: 40324
# Processing link: https://publicreporting.sts.org/gtsd-participant/40326
# Skipping already processed PID: 40326
# Processing link: https://publicreporting.sts.org/gtsd-participant/40325
# Skipping already processed PID: 40325
# Processing link: https://publicreporting.sts.org/gtsd-participant/40419
# Skipping already processed PID: 40419
# Processing link: https://publicreporting.sts.org/gtsd-participant/40051
# Skipping already processed PID: 40051
# Processing link: https://publicreporting.sts.org/gtsd-participant/40416
# Skipping already processed PID: 40416
# Skipping already processed PID: 40416
# Processing link: https://publicreporting.sts.org/gtsd-participant/40154
# Skipping already processed PID: 40154
# Processing link: https://publicreporting.sts.org/gtsd-participant/40130
# Skipping already processed PID: 40130
# Processing link: https://publicreporting.sts.org/gtsd-participant/40322
# Skipping already processed PID: 40322
# Processing link: https://publicreporting.sts.org/gtsd-participant/40321
# Skipping already processed PID: 40321
# Processing link: https://publicreporting.sts.org/gtsd-participant/40100
# Skipping already processed PID: 40100
# Processing link: https://publicreporting.sts.org/gtsd-participant/41157
# Skipping already processed PID: 41157
# Processing link: https://publicreporting.sts.org/gtsd-participant/41156
# Skipping already processed PID: 41156
# Processing link: https://publicreporting.sts.org/gtsd-participant/41154
# Skipping already processed PID: 41154
# Processing link: https://publicreporting.sts.org/gtsd-participant/40406
# Skipping already processed PID: 40406
# Processing link: https://publicreporting.sts.org/gtsd-participant/40129
# Skipping already processed PID: 40129
# Processing link: https://publicreporting.sts.org/gtsd-participant/40461
# Skipping already processed PID: 40461
# Processing link: https://publicreporting.sts.org/gtsd-participant/40081
# Skipping already processed PID: 40081
# Processing page: 1, found 48 links
# Processing link: https://publicreporting.sts.org/gtsd-participant/40058
# Skipping already processed PID: 40058
# Processing link: https://publicreporting.sts.org/gtsd-participant/40405
# Skipping already processed PID: 40405
# Processing link: https://publicreporting.sts.org/gtsd-participant/40337
# Skipping already processed PID: 40337
# Processing link: https://publicreporting.sts.org/gtsd-participant/40333
# Skipping already processed PID: 40333
# Processing link: https://publicreporting.sts.org/gtsd-participant/41018
# Skipping already processed PID: 41018
# Processing link: https://publicreporting.sts.org/gtsd-participant/40392
# Skipping already processed PID: 40392
# Processing link: https://publicreporting.sts.org/gtsd-participant/40164
# Skipping already processed PID: 40164
# Processing link: https://publicreporting.sts.org/gtsd-participant/41130
# Skipping already processed PID: 41130
# Processing link: https://publicreporting.sts.org/gtsd-participant/41153
# Skipping already processed PID: 41153
# Processing link: https://publicreporting.sts.org/gtsd-participant/40408
# Skipping already processed PID: 40408
# Processing link: https://publicreporting.sts.org/gtsd-participant/40174
# Skipping already processed PID: 40174
# Processing link: https://publicreporting.sts.org/gtsd-participant/40395
# Skipping already processed PID: 40395
# Processing link: https://publicreporting.sts.org/gtsd-participant/40375
# Skipping already processed PID: 40375
# Processing link: https://publicreporting.sts.org/gtsd-participant/41005
# Skipping already processed PID: 41005
# Processing link: https://publicreporting.sts.org/gtsd-participant/40121
# Skipping already processed PID: 40121
# Processing link: https://publicreporting.sts.org/gtsd-participant/41026
# Skipping already processed PID: 41026
# Processing link: https://publicreporting.sts.org/gtsd-participant/40068
# Skipping already processed PID: 40068
# Processing link: https://publicreporting.sts.org/gtsd-participant/41023
# Skipping already processed PID: 41023
# Processing link: https://publicreporting.sts.org/gtsd-participant/40359
# Skipping already processed PID: 40359
# Processing link: https://publicreporting.sts.org/gtsd-participant/40235
# Skipping already processed PID: 40235
# Processing link: https://publicreporting.sts.org/gtsd-participant/40382
# Skipping already processed PID: 40382
# Processing link: https://publicreporting.sts.org/gtsd-participant/40062
# Skipping already processed PID: 40062
# Processing link: https://publicreporting.sts.org/gtsd-participant/40001
# Skipping already processed PID: 40001
# Skipping already processed PID: 40001
# Skipping already processed PID: 40001
# Processing page: 2, found 46 links
# Processing link: https://publicreporting.sts.org/gtsd-participant/41147
# Skipping already processed PID: 41147
# Processing link: https://publicreporting.sts.org/gtsd-participant/40265
# Skipping already processed PID: 40265
# Processing link: https://publicreporting.sts.org/gtsd-participant/40177
# Skipping already processed PID: 40177
# Processing link: https://publicreporting.sts.org/gtsd-participant/40019
# Skipping already processed PID: 40019
# Processing link: https://publicreporting.sts.org/gtsd-participant/40102
# Skipping already processed PID: 40102
# Processing link: https://publicreporting.sts.org/gtsd-participant/41008
# Skipping already processed PID: 41008
# Processing link: https://publicreporting.sts.org/gtsd-participant/40377
# Skipping already processed PID: 40377
# Processing link: https://publicreporting.sts.org/gtsd-participant/40210
# Skipping already processed PID: 40210
# Processing link: https://publicreporting.sts.org/gtsd-participant/40025
# Skipping already processed PID: 40025
# Processing link: https://publicreporting.sts.org/gtsd-participant/40285
# Skipping already processed PID: 40285
# Processing link: https://publicreporting.sts.org/gtsd-participant/40083
# Skipping already processed PID: 40083
# Processing link: https://publicreporting.sts.org/gtsd-participant/40394
# Skipping already processed PID: 40394
# Skipping already processed PID: 40394
# Processing link: https://publicreporting.sts.org/gtsd-participant/40155
# Skipping already processed PID: 40155
# Processing link: https://publicreporting.sts.org/gtsd-participant/40363
# Skipping already processed PID: 40363
# Skipping already processed PID: 40363
# Processing link: https://publicreporting.sts.org/gtsd-participant/41006
# Skipping already processed PID: 41006
# Processing link: https://publicreporting.sts.org/gtsd-participant/40288
# Skipping already processed PID: 40288
# Processing link: https://publicreporting.sts.org/gtsd-participant/40084
# Skipping already processed PID: 40084
# Processing link: https://publicreporting.sts.org/gtsd-participant/41169
# Skipping already processed PID: 41169
# Skipping already processed PID: 41169
# Skipping already processed PID: 41169
# Processing link: https://publicreporting.sts.org/gtsd-participant/40305
# Skipping already processed PID: 40305
# Processing link: https://publicreporting.sts.org/gtsd-participant/40080
# Skipping already processed PID: 40080
# Processing link: https://publicreporting.sts.org/gtsd-participant/40302
# Skipping already processed PID: 40302
# Processing page: 3, found 43 links
# Processing link: https://publicreporting.sts.org/gtsd-participant/40422
# Skipping already processed PID: 40422
# Processing link: https://publicreporting.sts.org/gtsd-participant/40125
# Skipping already processed PID: 40125
# Processing link: https://publicreporting.sts.org/gtsd-participant/40211
# Skipping already processed PID: 40211
# Processing link: https://publicreporting.sts.org/gtsd-participant/40212
# Skipping already processed PID: 40212
# Processing link: https://publicreporting.sts.org/gtsd-participant/40213
# Skipping already processed PID: 40213
# Processing link: https://publicreporting.sts.org/gtsd-participant/40462
# Skipping already processed PID: 40462
# Processing link: https://publicreporting.sts.org/gtsd-participant/40018
# Skipping already processed PID: 40018
# Processing link: https://publicreporting.sts.org/gtsd-participant/40021
# Skipping already processed PID: 40021
# Processing link: https://publicreporting.sts.org/gtsd-participant/40022
# Skipping already processed PID: 40022
# Skipping already processed PID: 40022
# Processing link: https://publicreporting.sts.org/gtsd-participant/40229
# Skipping already processed PID: 40229
# Processing link: https://publicreporting.sts.org/gtsd-participant/40228
# Skipping already processed PID: 40228
# Processing link: https://publicreporting.sts.org/gtsd-participant/40460
# Skipping already processed PID: 40460
# Processing link: https://publicreporting.sts.org/gtsd-participant/40398
# Skipping already processed PID: 40398
# Skipping already processed PID: 40398
# Skipping already processed PID: 40398
# Skipping already processed PID: 40398
# Skipping already processed PID: 40398
# Processing link: https://publicreporting.sts.org/gtsd-participant/40016
# Skipping already processed PID: 40016
# Skipping already processed PID: 40016
# Skipping already processed PID: 40016
# Processing link: https://publicreporting.sts.org/gtsd-participant/40047
# Skipping already processed PID: 40047
# Processing link: https://publicreporting.sts.org/gtsd-participant/40255
# Skipping already processed PID: 40255
# Processing link: https://publicreporting.sts.org/gtsd-participant/40440
# Skipping already processed PID: 40440
# Processing link: https://publicreporting.sts.org/gtsd-participant/40076
# Skipping already processed PID: 40076
# Processing page: 4, found 48 links
# Processing link: https://publicreporting.sts.org/gtsd-participant/41133
# Skipping already processed PID: 41133
# Processing link: https://publicreporting.sts.org/gtsd-participant/40271
# Skipping already processed PID: 40271
# Processing link: https://publicreporting.sts.org/gtsd-participant/40038
# Skipping already processed PID: 40038
# Processing link: https://publicreporting.sts.org/gtsd-participant/40346
# Skipping already processed PID: 40346
# Processing link: https://publicreporting.sts.org/gtsd-participant/40116
# Skipping already processed PID: 40116
# Processing link: https://publicreporting.sts.org/gtsd-participant/40365
# Skipping already processed PID: 40365
# Processing link: https://publicreporting.sts.org/gtsd-participant/40079
# Skipping already processed PID: 40079
# Processing link: https://publicreporting.sts.org/gtsd-participant/40071
# Skipping already processed PID: 40071
# Processing link: https://publicreporting.sts.org/gtsd-participant/40031
# Skipping already processed PID: 40031
# Processing link: https://publicreporting.sts.org/gtsd-participant/40353
# Skipping already processed PID: 40353
# Processing link: https://publicreporting.sts.org/gtsd-participant/40106
# Skipping already processed PID: 40106
# Processing link: https://publicreporting.sts.org/gtsd-participant/40449
# Skipping already processed PID: 40449
# Skipping already processed PID: 40449
# Processing link: https://publicreporting.sts.org/gtsd-participant/40118
# Skipping already processed PID: 40118
# Processing link: https://publicreporting.sts.org/gtsd-participant/41146
# Skipping already processed PID: 41146
# Processing link: https://publicreporting.sts.org/gtsd-participant/40178
# Skipping already processed PID: 40178
# Processing link: https://publicreporting.sts.org/gtsd-participant/40317
# Skipping already processed PID: 40317
# Processing link: https://publicreporting.sts.org/gtsd-participant/40167
# Skipping already processed PID: 40167
# Processing link: https://publicreporting.sts.org/gtsd-participant/40087
# Skipping already processed PID: 40087
# Processing link: https://publicreporting.sts.org/gtsd-participant/40085
# Skipping already processed PID: 40085
# Skipping already processed PID: 40085
# Processing link: https://publicreporting.sts.org/gtsd-participant/40186
# Skipping already processed PID: 40186
# Processing link: https://publicreporting.sts.org/gtsd-participant/40230
# Skipping already processed PID: 40230
# Processing link: https://publicreporting.sts.org/gtsd-participant/40261
# Skipping already processed PID: 40261
# Processing link: https://publicreporting.sts.org/gtsd-participant/40136
# Skipping already processed PID: 40136
# Processing page: 5, found 50 links
# Processing link: https://publicreporting.sts.org/gtsd-participant/40361
# Skipping already processed PID: 40361
# Processing link: https://publicreporting.sts.org/gtsd-participant/40362
# Skipping already processed PID: 40362
# Processing link: https://publicreporting.sts.org/gtsd-participant/40364
# Skipping already processed PID: 40364
# Processing link: https://publicreporting.sts.org/gtsd-participant/41003
# Skipping already processed PID: 41003
# Processing link: https://publicreporting.sts.org/gtsd-participant/40356
# Skipping already processed PID: 40356
# Processing link: https://publicreporting.sts.org/gtsd-participant/40120
# Skipping already processed PID: 40120
# Processing link: https://publicreporting.sts.org/gtsd-participant/40003
# Skipping already processed PID: 40003
# Processing link: https://publicreporting.sts.org/gtsd-participant/40446
# Skipping already processed PID: 40446
# Processing link: https://publicreporting.sts.org/gtsd-participant/40053
# Skipping already processed PID: 40053
# Processing link: https://publicreporting.sts.org/gtsd-participant/40166
# Skipping already processed PID: 40166
# Processing link: https://publicreporting.sts.org/gtsd-participant/40002
# Skipping already processed PID: 40002
# Processing link: https://publicreporting.sts.org/gtsd-participant/40268
# Skipping already processed PID: 40268
# Processing link: https://publicreporting.sts.org/gtsd-participant/40370
# Skipping already processed PID: 40370
# Processing link: https://publicreporting.sts.org/gtsd-participant/41142
# Skipping already processed PID: 41142
# Processing link: https://publicreporting.sts.org/gtsd-participant/40379
# Skipping already processed PID: 40379
# Processing link: https://publicreporting.sts.org/gtsd-participant/40387
# Skipping already processed PID: 40387
# Processing link: https://publicreporting.sts.org/gtsd-participant/41134
# Skipping already processed PID: 41134
# Processing link: https://publicreporting.sts.org/gtsd-participant/40277
# Skipping already processed PID: 40277
# Processing link: https://publicreporting.sts.org/gtsd-participant/40123
# Skipping already processed PID: 40123
# Processing link: https://publicreporting.sts.org/gtsd-participant/40157
# Skipping already processed PID: 40157
# Processing link: https://publicreporting.sts.org/gtsd-participant/40304
# Skipping already processed PID: 40304
# Processing link: https://publicreporting.sts.org/gtsd-participant/40227
# Skipping already processed PID: 40227
# Processing link: https://publicreporting.sts.org/gtsd-participant/40345
# Skipping already processed PID: 40345
# Processing link: https://publicreporting.sts.org/gtsd-participant/40351
# Skipping already processed PID: 40351
# Processing link: https://publicreporting.sts.org/gtsd-participant/40202
# Skipping already processed PID: 40202
# Processing page: 6, found 48 links
# Processing link: https://publicreporting.sts.org/gtsd-participant/40300
# Skipping already processed PID: 40300
# Processing link: https://publicreporting.sts.org/gtsd-participant/40113
# Skipping already processed PID: 40113
# Skipping already processed PID: 40113
# Skipping already processed PID: 40113
# Processing link: https://publicreporting.sts.org/gtsd-participant/41024
# Skipping already processed PID: 41024
# Processing link: https://publicreporting.sts.org/gtsd-participant/40095
# Skipping already processed PID: 40095
# Processing link: https://publicreporting.sts.org/gtsd-participant/40128
# Skipping already processed PID: 40128
# Processing link: https://publicreporting.sts.org/gtsd-participant/40390
# Skipping already processed PID: 40390
# Processing link: https://publicreporting.sts.org/gtsd-participant/40162
# Skipping already processed PID: 40162
# Processing link: https://publicreporting.sts.org/gtsd-participant/41150
# Skipping already processed PID: 41150
# Processing link: https://publicreporting.sts.org/gtsd-participant/40424
# Skipping already processed PID: 40424
# Processing link: https://publicreporting.sts.org/gtsd-participant/40093
# Skipping already processed PID: 40093
# Processing link: https://publicreporting.sts.org/gtsd-participant/40199
# Skipping already processed PID: 40199
# Processing link: https://publicreporting.sts.org/gtsd-participant/40215
# Skipping already processed PID: 40215
# Processing link: https://publicreporting.sts.org/gtsd-participant/41165
# Skipping already processed PID: 41165
# Processing link: https://publicreporting.sts.org/gtsd-participant/40348
# Skipping already processed PID: 40348
# Processing link: https://publicreporting.sts.org/gtsd-participant/40028
# Skipping already processed PID: 40028
# Processing link: https://publicreporting.sts.org/gtsd-participant/40150
# Skipping already processed PID: 40150
# Processing link: https://publicreporting.sts.org/gtsd-participant/40017
# Skipping already processed PID: 40017
# Processing link: https://publicreporting.sts.org/gtsd-participant/40006
# Skipping already processed PID: 40006
# Processing link: https://publicreporting.sts.org/gtsd-participant/40009
# Skipping already processed PID: 40009
# Processing link: https://publicreporting.sts.org/gtsd-participant/40225
# Skipping already processed PID: 40225
# Processing link: https://publicreporting.sts.org/gtsd-participant/40010
# Skipping already processed PID: 40010
# Processing link: https://publicreporting.sts.org/gtsd-participant/40146
# Skipping already processed PID: 40146
# Processing link: https://publicreporting.sts.org/gtsd-participant/40059
# Skipping already processed PID: 40059
# Processing page: 7, found 36 links
# Processing link: https://publicreporting.sts.org/gtsd-participant/40127
# Skipping already processed PID: 40127
# Processing link: https://publicreporting.sts.org/gtsd-participant/40438
# Skipping already processed PID: 40438
# Processing link: https://publicreporting.sts.org/gtsd-participant/40357
# Skipping already processed PID: 40357
# Processing link: https://publicreporting.sts.org/gtsd-participant/40052
# Skipping already processed PID: 40052
# Processing link: https://publicreporting.sts.org/gtsd-participant/40032
# Skipping already processed PID: 40032
# Processing link: https://publicreporting.sts.org/gtsd-participant/40276
# Skipping already processed PID: 40276
# Skipping already processed PID: 40276
# Skipping already processed PID: 40276
# Skipping already processed PID: 40276
# Skipping already processed PID: 40276
# Skipping already processed PID: 40276
# Processing link: https://publicreporting.sts.org/gtsd-participant/40134
# Skipping already processed PID: 40134
# Processing link: https://publicreporting.sts.org/gtsd-participant/41144
# Skipping already processed PID: 41144
# Processing link: https://publicreporting.sts.org/gtsd-participant/40292
# Skipping already processed PID: 40292
# Processing link: https://publicreporting.sts.org/gtsd-participant/41152
# Skipping already processed PID: 41152
# Processing link: https://publicreporting.sts.org/gtsd-participant/40193
# Skipping already processed PID: 40193
# Processing link: https://publicreporting.sts.org/gtsd-participant/40437
# Skipping already processed PID: 40437
# Processing link: https://publicreporting.sts.org/gtsd-participant/40301
# Skipping already processed PID: 40301
# Skipping already processed PID: 40301
# Processing link: https://publicreporting.sts.org/gtsd-participant/40425
# Skipping already processed PID: 40425
# Processing link: https://publicreporting.sts.org/gtsd-participant/40105
# Skipping already processed PID: 40105
# Processing page: 8, found 0 links
# Data exported to CSV
